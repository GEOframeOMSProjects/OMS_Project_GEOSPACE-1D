# %% [markdown]
# # This Notebooks explains how to run OMS3 projects from Jupyter Notebooks

# %% [markdown]
# Authors: Martin Morlot, Riccardo Rigon
#
# Martin created the scripts for executing the commands. Riccardo prepared this Notebook and comments and did the small final script
# using this resource: https://stackabuse.com/executing-shell-commands-with-python/

# %% [markdown]
# Distributed under GPL 3.0

# %% [markdown]
# To run OMS projects you need to know what they are. Please refers to https://geoframe.blogspot.com/2022/05/gss2022-installations-may-16-2022.html

# %%
import os
import sys
import subprocess

# %%
#To be added to geoframe.py
# Improvable with more controls and more pythonic setting of global variables
# Using https://stackabuse.com/executing-shell-commands-with-python/
def OMS_run_MAC(simulation):
    sim=simulation+".sim"
    if(JAVA_HOME==''):
        print("JAVA_HOME not set")
        return -1
    else:
        com=JAVA_HOME+'java'
    if(console_location ==''):
        print("console location not found")
        return -1
    proj_loc=os. getcwd()
    total_cmd=[com,'-Doms3.work='+proj_loc,'-cp','.:'+console_location+'/*:lib/*:dist/*','oms3.CLI', '-r','simulation/'+sim]
    useless_cat_call = subprocess.Popen(total_cmd, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    output, errors = useless_cat_call.communicate(input="Hello from the other side!")
    useless_cat_call.wait()
    return output,errors

def OMS_run_WINDOWS(simulation):
    sim=simulation+".sim"
    if(JAVA_HOME==''):
        print("JAVA_HOME not set")
        return -1
    else:
        com=JAVA_HOME+'java'
    if(console_location ==''):
        print("console location not found")
        return -1
    proj_loc=os. getcwd()
    total_cmd=[com,'-Doms3.work='+proj_loc,'-cp','.;'+console_location+'/*;lib/*;dist/*','oms3.CLI', '-r','simulation/'+sim]
    useless_cat_call = subprocess.Popen(total_cmd, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    output, errors = useless_cat_call.communicate(input="Hello from the other side!")
    useless_cat_call.wait()
    return output,errors

# %%
JAVA_HOME="/Users/concettadamato/opt/anaconda3/envs/geoframe_vincennes/lib/jvm/bin/"
console_location = "/Users/concettadamato/OMS/consoleOMS/oms-3.6.28-console/"

proj_location = "/Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D"
os.chdir(proj_location)
#Actual Execution
output,errors=OMS_run_MAC('GEOSPACE1D_ProsperoPM')
print(output)
# Out:
# Reading features from shapefile: centroid.shp
#
#
# 	*** SUCCESS reading /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//data/Grid_NetCDF/Grid_GEOSPACE_test.nc
# Reading coverage: DemSpikeIIcut.tif
# Finished.
# Finished.
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# GE = 0,62789
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 0,00000
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain
# 	***Created NetCDF /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# 		*** 2018-05-10 00:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# GE = 0,62789
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 0,00000
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 01:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# GE = 0,62789
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 0,00000
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 02:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# GE = 0,62789
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 0,00000
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 03:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# GE = 0,62789
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 0,00000
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 04:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# GE = 0,62789
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 0,00000
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 05:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# GE = 0,62789
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 57,98226
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 06:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77965
# GE = 0,62768
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 105,46408
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 07:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77994
# GE = 0,64190
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 158,70775
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 08:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78177
# GE = 0,68612
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 224,05182
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 09:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78322
# GE = 0,72679
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 254,36769
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 10:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78413
# GE = 0,75916
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 263,40607
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 11:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78454
# GE = 0,78306
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 236,06159
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,00000
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 12:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78473
# GE = 0,80082
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 222,83264
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,02502
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 13:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78388
# GE = 0,80046
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 227,44132
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,53528
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 14:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78290
# GE = 0,79873
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 290,18494
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 3,10992
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 15:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78153
# GE = 0,79613
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 200,19804
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 1,77171
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 16:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78063
# GE = 0,79353
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 102,87642
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,72936
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 17:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78025
# GE = 0,79099
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 41,83438
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 1,14407
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 18:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78019
# GE = 0,78838
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 14,48309
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 0,07674
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10
00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92532
# GE = 0,78299
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 567,89485
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 22,02978
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 18:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92283
# GE = 0,77968
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 402,60284
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 13,81930
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 19:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92099
# GE = 0,77742
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 272,85783
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 8,69649
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 20:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91967
# GE = 0,77591
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 278,10634
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 9,22661
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 21:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91832
# GE = 0,77432
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 280,83468
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 9,94329
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 22:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91696
# GE = 0,77267
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 244,21364
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 8,53588
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 23:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91575
# GE = 0,77123
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 192,00345
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 6,29211
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 00:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91475
# GE = 0,77010
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 143,77842
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 4,45830
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 01:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91395
# GE = 0,76923
# End JarvisStressFactorSolverMain
#
# Start ProsperoSolverMain
# flux transpiration = 112,15698
#
# End ProsperoSolverMain
#
# Start PMEvaporationFromSoilSolverMain
# flux evaporation = 3,15045
#
# End PMEvaporationFromSoilSolverMain
#
# Start TotalEvapoTranspirationSolverMain
# End TotalEvapoTranspirationSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
#
# Controllo su fluxs Average corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 02:00, writing output file: /Users/concettadamato/Desktop/TESIPHD/02_Supplementary_PhDThesisCD/OMS_Project_GEOSPACE1D//output/SpikeII/OMS_Spike_test_0000.nc

# %%
print(errors)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.codehaus.groovy.reflection.CachedClass$3$1 (file:/Users/concettadamato/OMS/consoleOMS/oms-3.6.28-console/lib/groovy-all-2.3.9.jar) to method java.lang.Object.finalize()
# WARNING: Please consider reporting this to the maintainers of org.codehaus.groovy.reflection.CachedClass$3$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# mag 26, 2024 11:29:11 PM org.hsqldb.persist.Logger logInfoEvent
# INFORMAZIONI: dataFileCache open start

# %%
JAVA_HOME="/Users/concettadamato/opt/anaconda3/envs/geoframe_vincennes/lib/jvm/bin/"
console_location = "/Users/concettadamato/OMS/consoleOMS/oms-3.6.28-console/"

proj_location = "/Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D"
os.chdir(proj_location)
#Actual Execution
output,errors=OMS_run_MAC('GEOSPACE1D_PriestleyTaylor')
print(output)
# Out:
# Reading features from shapefile: centroid.shp
#
#
# 	*** SUCCESS reading /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//data/Grid_NetCDF/Grid_GEOSPACE_test.nc
# Reading coverage: DemSpikeIIcut.tif
# Finished.
# Finished.
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain
# 	***Created NetCDF /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# 		*** 2018-05-10 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77994
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78073
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78336
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78589
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78804
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78971
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79104
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79125
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79136
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79142
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79148
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79155
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79168
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79182
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79195
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79207
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79219
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79231
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79242
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79252
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79262
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79272
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79282
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79291
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79297
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79264
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79189
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79083
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78953
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78804
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78647
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78488
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78337
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78205
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78102
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78033
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78027
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78034
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78043
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78068
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78301
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78602
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78925
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79273
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79644
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,80048
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,80486
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,80938
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,81403
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,81852
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,82285
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,82704
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,83094
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,83464
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,83813
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,84138
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,84469
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,84787
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,85087
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,85364
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,85639
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,85894
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,86134
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,86374
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,86646
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,87004
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,87477
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,88037
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,88631
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,89203
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,89757
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,90280
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,90771
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91247
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91707
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92150
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92575
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92987
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,93379
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,93761
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,94131
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,94494
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,94854
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,95211
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# ...
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-27 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99953
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-27 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99948
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-27 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99944
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-27 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99939
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99934
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99930
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99924
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99919
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99914
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99908
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99902
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99894
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99883
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99870
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99855
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99837
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99817
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99796
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99774
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99752
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99733
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99719
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99707
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99696
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99686
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99677
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99666
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99656
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99646
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99635
# End JarvisStressFactorSolverMain
#
# Start PriestleyTaylorActualETSolverMain
#
# End PriestleyTaylorActualETSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PT_test_0000.nc

# %%
print(errors)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.codehaus.groovy.reflection.CachedClass$3$1 (file:/Users/concettadamato/OMS/consoleOMS/oms-3.6.28-console/lib/groovy-all-2.3.9.jar) to method java.lang.Object.finalize()
# WARNING: Please consider reporting this to the maintainers of org.codehaus.groovy.reflection.CachedClass$3$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# mag 27, 2024 8:21:54 PM org.hsqldb.persist.Logger logInfoEvent
# INFORMAZIONI: dataFileCache open start

# %%
JAVA_HOME="/Users/concettadamato/opt/anaconda3/envs/geoframe_vincennes/lib/jvm/bin/"
console_location = "/Users/concettadamato/OMS/consoleOMS/oms-3.6.28-console/"

proj_location = "/Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D"
os.chdir(proj_location)
#Actual Execution
output,errors=OMS_run_MAC('GEOSPACE1D_PenmanMonteithFAO')
print(output)
# Out:
# Reading features from shapefile: centroid.shp
#
#
# 	*** SUCCESS reading /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//data/Grid_NetCDF/Grid_GEOSPACE_test.nc
# Reading coverage: DemSpikeIIcut.tif
# Finished.
# Finished.
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain
# 	***Created NetCDF /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# 		*** 2018-05-10 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77996
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,77994
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78075
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78338
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78595
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78812
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78983
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79118
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79143
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79156
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79162
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79169
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79177
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79190
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79203
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79216
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79228
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79239
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-10 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79249
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79258
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79268
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79278
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79287
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79296
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79304
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79310
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79286
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79229
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79150
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79054
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78944
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78826
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78706
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78591
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78487
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78405
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78350
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78341
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78346
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78353
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78378
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78611
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-11 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,78911
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79233
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79578
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,79949
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,80353
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,80792
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,81244
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,81709
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,82162
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,82606
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,83045
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,83463
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,83856
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,84240
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,84601
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,84953
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,85288
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,85593
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,85876
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,86150
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,86400
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,86639
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,86876
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,87145
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-12 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,87495
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,87960
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,88512
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,89087
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,89650
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,90188
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,90703
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91196
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,91669
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92123
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92561
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,92982
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,93391
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,93783
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,94156
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,94521
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-05-13 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,94882
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# ...
# G = 0,99992
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-27 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99990
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-27 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99988
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-27 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99985
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99983
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99980
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99977
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 03:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99974
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 04:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99970
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 05:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99967
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 06:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99963
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 07:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99958
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 08:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99952
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 09:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99945
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 10:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99936
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 11:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99926
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 12:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99914
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 13:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99902
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 14:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99889
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 15:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99876
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 16:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99864
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 17:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99854
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 18:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99844
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 19:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99836
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 20:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99827
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 21:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99819
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 22:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99810
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-28 23:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99801
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 00:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99793
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 01:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc
#
#
# Start InputReaderMain
#
# End InputReaderMain
#
# Start RootDensitySolverMain
# End RootDensitySolverMain
#
# Start JarvisStressFactorSolverMain
# G = 0,99784
# End JarvisStressFactorSolverMain
#
# Start PenmanMonteithFAOTotalStressedSolverMain
# End PenmanMonteithFAOTotalStressedSolverMain
#
# Start InputDataMain
# End InputDataMain
#
# Start ETsBrokerSolverMain
#
# Controllo su fluxs Root corretto"
#
# End ETsBrokerSolverMain		*** 2018-06-29 02:00, writing output file: /Users/concettadamato/OMS/OMS_Project_GEOSPACE-1D//output/SpikeII/OMS_Spike_PM_test_0000.nc

# %%
print(errors)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.codehaus.groovy.reflection.CachedClass$3$1 (file:/Users/concettadamato/OMS/consoleOMS/oms-3.6.28-console/lib/groovy-all-2.3.9.jar) to method java.lang.Object.finalize()
# WARNING: Please consider reporting this to the maintainers of org.codehaus.groovy.reflection.CachedClass$3$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# mag 27, 2024 8:23:43 PM org.hsqldb.persist.Logger logInfoEvent
# INFORMAZIONI: dataFileCache open start
